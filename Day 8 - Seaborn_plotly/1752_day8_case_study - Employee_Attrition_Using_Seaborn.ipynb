# %% [markdown]
# #Data Visualization Using Seaborn
#
# ###Case Study - IBM HR Analytics Employee Attrition and Performance

# %% [markdown]
# - Seaborn is a Python data visualization library based on matplotlib
# - It provides a high-level interface for drawing attractive and informative statistical graphics

# %% [markdown]
# ![IBM.png](data:image/png;base64,...)

# %% [markdown]
# ### Business Scenario:
#
# Employee retention is one of the biggest metrics that a company should have in mind when thinking of growth. Employee attrition is caused when the total strength of the company is greatly reduced as more employees leave the company than expected.
#
# So, what is **Attrition**?
# It is basically the turnover rate of employees in a particular organization
#
# Reasons for **Attrition**:
#
# - Employees looking for better opportunities
# - A negative working environment
# - Bad management
# - Sickness of an employee
# - Excessive working hours
#
# Note: This is Fictional dataset created by IBM Data Scientists

# %% [markdown]
# ### Objective:
#
# Uncover the factors that lead to employee attrition and explore the reasons as to why people are leaving the organization

# %% [markdown]
# ### **Dataset Attributes**
# The is a data set contains following attributes among others
#
# **Education**
#
# 1 'Below College'
#
# 2 'College'
#
# 3 'Bachelor'
#
# 4 'Master'
#
# 5 'Doctor'
#
# **EnvironmentSatisfaction**
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'
#
#
# **JobInvolvement**
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'
#
#
# **JobSatisfaction**
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'
#
#
# **PerformanceRating**
#
# 1 'Low'
#
# 2 'Good'
#
# 3 'Excellent'
#
# 4 'Outstanding'
#
#
# **RelationshipSatisfaction**
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'
#
# **WorkLifeBalance**
#
# 1 'Bad'
#
# 2 'Good'
#
# 3 'Better'
#
# 4 'Best'

# %% [markdown]
# ### **Importing Required Libraries & Loading the Dataset**

# %%
# !wget https://www.dropbox.com/s/53xyievbdpr7bl0/IBM.csv
# Out:
# --2022-04-12 06:45:05--  https://www.dropbox.com/s/53xyievbdpr7bl0/IBM.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/53xyievbdpr7bl0/IBM.csv [following]
# --2022-04-12 06:45:05--  https://www.dropbox.com/s/raw/53xyievbdpr7bl0/IBM.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1d16b3d49ab5b5cb2392a277fb.dl.dropboxusercontent.com/cd/0/inline/BjPMoUwZI9VVQQMcyjAsraATAlxEvd6DbEkYivxnSgtFQ9Nih_SsM6jjOC5xo-aWSLfx41jVXooCVfWjke5yrHCyC_VJBBFS7-vP7SJFagiGx6fHpz4kom2yKRGelN_AAGRJ3U6hEdnrfs0Si1pCpAptw0qsSUi0SZbLSGkILzYWxw/file# [following]
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")    
import os

# %%
df = pd.read_csv('IBM.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### **1. What is the Salary trend based on their Job Role?**

# %%
f,ax=plt.subplots(figsize=(20,10))
sns.lineplot(x='JobRole', y='MonthlyIncome', data=df,ax=ax)

# %% [markdown]
# #### **2. Customize line plot by providing title**

# %%
f,ax=plt.subplots(figsize=(20,10))
sns.lineplot(x='JobRole', y='MonthlyIncome', data=df,ax=ax).set(xlabel='Job Role', ylabel='Income', title='Line plot - Job Role vs. Monthly Income')
# Out:
# [Text(0, 0.5, 'Income'),
#  Text(0.5, 0, 'Job Role'),
#  Text(0.5, 1.0, 'Line plot - Job Role vs. Monthly Income')]

# %% [markdown]
# #### **3. Visualize the trend based on Gender**

# %%
f,ax=plt.subplots(figsize=(20,10))
sns.lineplot(x='JobRole', y='MonthlyIncome',hue='Gender', err_style='bars',data=df,ax=ax).set(xlabel='Job Role', ylabel='Income', title='Line plot - Job Role vs. Monthly Income')
# Out:
# [Text(0, 0.5, 'Income'),
#  Text(0.5, 0, 'Job Role'),
#  Text(0.5, 1.0, 'Line plot - Job Role vs. Monthly Income')]

# %% [markdown]
# ### Inference:
#
# 1. Line plot usually shows the trend over time
# 2. We can also say that there is no Gender Discrimination towards Salary
# 3. However, Manager and Research Director earns the highest salaries. Sales Representatives, Research Scientist and Laboratory Technician earns the lowest salaries respectively

# %% [markdown]
# #### **4. Which gender is more likely to leave?**

# %%
sns.barplot(x = 'Attrition', y = 'MonthlyIncome', data = df)

# %% [markdown]
# ### Inference:
#
# From above, we can see that people with low monthly income are more likely to leave as compared to people with high monthly income

# %% [markdown]
# #### **5. Does distance from home affect attrition rate?**

# %%
f,ax = plt.subplots()
new_df = df["Gender"].groupby(df["Attrition"]).value_counts(normalize = True).rename("Percentage of group").reset_index()

sns.barplot(x = "Attrition", y = "Percentage of group", hue = "Gender", data = new_df)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

ax.set(title = "Distribution of gender")
# Out:
# [Text(0.5, 1.0, 'Distribution of gender')]

# %% [markdown]
# ### Inference:
#
# The company has more men than women, and so this plot tells us that men tend to leave the company more but only because they're in a larger number. This also indicates that gender might not be a key factor for employee attrition

# %% [markdown]
# #### **6. How does the monthly income affect the attrition rate?**

# %%
sns.barplot(df['Gender'],df['DistanceFromHome'],hue = df['Attrition'])

# %% [markdown]
# ### Inference:
#
# 1. Distance from home matters more to women employees than men
# 2. Employee are more likely to quit, when **DistanceFromHome** is above 8 km

# %% [markdown]
# #### **7. Which Employees are more likely to leave? Senior Employees or Recent Joinees, and does the years spent at the company affect Attrition?**

# %%
sns.scatterplot(x=df['MonthlyIncome'],y=df['YearsAtCompany'],hue=df['Attrition'])

# %% [markdown]
# ### Inference:
#
# 1. Majortiy of Employee fall in the monthly income category of 2500 to 10000
# 2. Senior Employees with higher **MonthlyIncome** who have spent more number of years at company are less likely to leave as compared to recent joinees
# 3. New Employees (less than 2 years at Company i.e., y-axis) with less **MonthlyIncome** are more likely to quit (Consider the blue dots)
# 4. Employees with higher experience (8 to 10 years) with low wage are more likely to leave

# %% [markdown]
# #### **8. What is the distribution of the Age & MothlyIncome columns in the data set?**

# %%
sns.distplot(df['Age'], kde = False)
plt.ylabel('No. of Observations')
# Out:
# Text(0, 0.5, 'No. of Observations')

# %% [markdown]
# **Note:** By default, **distplot** function draw a histogram and fit a kernel density estimate (KDE)

# %% [markdown]
# ### Inference:
#
# We have Employees mostly between the age of 30 to 45

# %%
sns.distplot(df['MonthlyIncome'], kde = False) 
plt.ylabel('No. of Observations')
# Out:
# Text(0, 0.5, 'No. of Observations')

# %% [markdown]
# ### Inference:
#
# 1. Most of the Employees in the company earn between 2000 and 7000 monthly
# 2. Very few Employees command a higher salary

# %% [markdown]
# #### **9. Analyze the Monthly Income of Employees in various Deparments such as Sales, Research & Development, and Human Resource?**

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Department",y="MonthlyIncome",data=df,palette="Set2")

# %% [markdown]
# If you want to learn more about Seaborn Color palettes [**Click Here!**](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %% [markdown]
# ### Inference:
#
# Most of the employees in various departments earn similar wage

# %% [markdown]
# #### **10. What is Percentage of Research Scientist in IBM?**

# %%
labels=df.JobRole.value_counts().index
colors=["olive","orange","hotpink","slateblue","y","lime"]
sizes=df.JobRole.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%")
plt.title("Percentage of Research Scientists",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of Research Scientists')

# %% [markdown]
# Parameters Used while plotting:
#
# 1. **Labels:** A sequence of strings providing the labels for each wedge
# 2. **Colors:** A sequence of matplotlibcolorargs through which the pie chart will cycle. If None, will use the colors in the currently active cycle
# 3. **Autopct:** Used to label the wedges with their numeric value. The label will be placed inside the wedge

# %% [markdown]
# Let us use explode to highlight only the Research Scientists from the chart

# %%
labels=df.JobRole.value_counts().index
colors=["olive","orange","hotpink","slateblue","y","lime"]
explode=[0,0.2,0,0,0,0,0,0,0]
sizes=df.JobRole.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",explode=explode)
plt.title("Percentage of Research Scientists",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of Research Scientists')

# %% [markdown]
# ### Inference:
#
# There are about 20% Research Scientists present in IBM. However, Sales Executives are more in Number

# %% [markdown]
# #### **11. Visualize the Correlation between all the features**

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt=".1f",ax=ax)

# %% [markdown]
# ### Inference:
#
# We can see that Current Manager is correlated with Job level, Years of Experience(Total working years, Years in current role) which is quite obvious becuase its one the highest designation in the company

# %% [markdown]
# #### 12. Plot heatmap considering only the important features from Q.11

# %%
#f,ax=plt.subplots(figsize=(20,20))
Imp_features=['YearsWithCurrManager','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole']
sns.heatmap(df[Imp_features].corr(),annot=True,linewidths=0.5,linecolor="black",fmt=".1f")
plt.show()
