# %% [markdown]
# #Python Basics
#
# ###Demo 3: Data Types in Python

# %% [markdown]
# ### Numbers

# %% [markdown]
# Payal is beginner in Python. She is just sitting outside and studying Python. Let us see how she applies Python here.

# %%
chickens = int(input('Number of chickens:'))
x = int(input("Enter your openion for number of eggs/checken"))
eggs = print("Number of eggs laid by the chickens---->", chickens*x)
# Out:
# Number of eggs laid by the chickens----> 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 4 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> x = int(input("Enter your openion for number of eggs/checken"))
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> eggs = print("Number of eggs laid by the chickens---->", chickens*x)
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> int(chickens)/int(eggs)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %% [markdown]
# Encountering Errors:

# %%
print('Number of eggs each chicken will lay?', int(eggs)/int(chickens))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> print('Number of eggs each chicken will lay?', int(eggs)/int(chickens))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %% [markdown]
# Type error. We cannot divide two strings.

# %% [markdown]
# She tries to rectify the error by converting type to integer

# %%
print('Number of eggs each chicken will lay?', map(float(eggs/chickens)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> print('Number of eggs each chicken will lay?', map(float(eggs/chickens)))
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
# It is not possible to lay half egg right?
each_chicken_egg = float(eggs/chickens)
print('Number of eggs each chicken will lay?', each_chicken_egg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # It is not possible to lay half egg right?
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> each_chicken_egg = float(eggs/chickens)
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> print('Number of eggs each chicken will lay?', each_chicken_egg)
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %% [markdown]
# Every chicken will give at least 1 egg. That makes sense. But there is one more problem:
# Which chickens are laying more eggs or vice versa.

# %%
# how many eggs all the chickens should lay? tuff...
eggs_presumed = float(each_chicken_egg)*float(chickens)
print('Total eggs all the chickens should lay:', eggs_presumed)
print('Total eggs laid originally:', eggs)
more_eggs = float(eggs)-eggs_presumed
print('number of chickens laying more eggs:', more_eggs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # how many eggs all the chickens should lay? tuff...
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> eggs_presumed = float(each_chicken_egg)*float(chickens)
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> print('Total eggs all the chickens should lay:', eggs_presumed)
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> print('Total eggs laid originally:', eggs)
#
# NameError: name 'each_chicken_egg' is not defined

# %%
# This is basic formatting in python
print('Means %i chickens are laying more than average eggs' %
      (more_eggs))  # This is basic formatting in python
# Out:
# Means 0 chickens are laying more than average eggs

# %% [markdown]
# Now, Payal wants to measure the area of the farm. She asks her dad to enter length and breadth of the farm.

# %%
# %i represents an integer value
length, breadth = input(
    'Enter length and breadth of the farm separated by comma:').split(',')
area = float(length)*float(breadth)
print('Area of field:', area)
# Out:
# Enter length and breadth of the farm separated by comma:12,12
# Area of field: 144.0

# %%
# Some of the land is used as grazing land. So, the usable area should be-
grazing_land = 200
area -= 200
print('Usable area:', area)
# Out:
# Usable area: -56.0

# %%
# Rest of the area is evenly divided into 7 parts
print('Area for each section:', area/7)
# Out:
# Area for each section: -8.0

# %%
# The precision level is to high, Payal needs just 4 decimal places
print('Area for each section %0.4f' % (area/7))
# Out:
# Area for each section -8.0000

# %%
# Formatting can also be done using format() function
print('Area for each section {:.3f}'.format(area/7))
# Out:
# Area for each section -8.000

# %%
# later she learnt how to use complex number in python
A = 10+3j
B = 5-10j

# %%
# operations on complex numbers
print('Addition of two complex numbers:', A+B)
print('Mulitplication of a complex number and an integer:', A*2)
print('Real part of a complex number:', A.real)
print('Conjugate of complex number:', A.conjugate())
print('Imaginary part of a complex number:', A.imag)
# Out:
# Addition of two complex numbers: (15-7j)
# Mulitplication of a complex number and an integer: (20+6j)
# Real part of a complex number: 10.0
# Conjugate of complex number: (10-3j)
# Imaginary part of a complex number: 3.0

# %%
# Comparision of real part to an integer
print(A.real == 10)
# Out:
# True

# %%
# left shift and right shift
# binary of 5= 00000101 so left shifting by two places
# 101(5) << 2 => 10100 which is 20 in decimal

5 << 2, 5 >> 2
# Out:
# (20, 1)

# %%
# To represent a number in various number systems
test = int(input('Enter a number:'))
print('octal %s:' % oct(test))
print('binary %s:' % bin(test))
print('hexadecimal %s:' % hex(test))
# why %s? these functions return specific value in string for representation
# Out:
# Enter a number:20
# octal 0o24:
# binary 0b10100:
# hexadecimal 0x14:

# %%
# Exponents and powers
print('2 to 5th power: %d' % 2**5)
print('three times ten to the fifth power: %d' %
      3e5)  # python supports E-notation
# Out:
# 2 to 5th power: 32
# three times ten to the fifth power: 300000

# %%
# While playing with numbers she noticed something unsual
print(1.1+2.2 == 3.3)
# Out:
# False

# %%
# How can that be possible?
x = 1.1+2.20
y = 3.3
print(x == y)
# Out:
# False

# %%
#  It due to machine error. Machines cannot store decimals precisely
print(x)
print(y)
# Out:
# 3.3000000000000003
# 3.3

# %%
''' Payal wants to convert temperature from Fahrenheit to Celcuis
    Let us try to help her
    She knows the Formula is: C = 5 / 9 * (F - 32)
    One more thing! This is how we write multiline comments in Python.
'''
F = int(input('Enter the temperature in fahrenheit: '))
C = 5/9*(F-32)
print('Celcuis: %0.2f' % C)
# Out:
# Enter the temperature in fahrenheit: 123
# Celcuis: 50.56

# %% [markdown]
# ### Strings

# %% [markdown]
# Besides numbers, Python can also manipulate strings. Strings can enclosed in single quotes (`'...'`) or double quotes (`"..."`) with the same result. Use `\` to escape quotes, that is, to use a quote within the string itself:

# %%
'spam eggs'  # Single quotes.
# Out:
# 'spam eggs'

# %%
'doesn\'t'  # Use \' to escape the single quote...
# Out:
# "doesn't"

# %%
"doesn't"  # ...or use double quotes instead.
# Out:
# "doesn't"

# %%
'"Yes," he said.'
# Out:
# '"Yes," he said.'

# %%
"\"Yes,\" he said."
# Out:
# '"Yes," he said.'

# %%
'"Isn\'t," she said.'
# Out:
# '"Isn\'t," she said.'

# %% [markdown]
# In the interactive interpreter and Jupyter notebooks, the output string is enclosed in quotes and special characters are escaped with backslashes. Although this output sometimes looks different from the input (the enclosing quotes could change), the two strings are equivalent. The string is enclosed in double quotes if the string contains a single quote and no double quotes, otherwise its enclosed in single quotes. The [`print()`](https://docs.python.org/3.6/library/functions.html#print) function produces a more readable output by omitting the enclosing quotes and by printing escaped and special characters:

# %%
'"Isn\'t," she said.'
# Out:
# '"Isn\'t," she said.'

# %%
print('"Isn\'t," she said.')
# Out:
# "Isn't," she said.

# %%
s = 'First line.\nSecond line.'  # \n means newline.
s  # Without print(), \n is included in the output.
# Out:
# 'First line.\nSecond line.'

# %%
print(s)  # With print(), \n produces a new line.
# Out:
# First line.
# Second line.

# %% [markdown]
# If you don't want escaped characters (prefaced by `\`) to be interpreted as special characters, use *raw strings* by adding an `r` before the first quote:

# %%
print('C:\some\name')  # Here \n means newline!
# Out:
# C:\some
# ame

# %%
print(r'C:\some\name')  # Note the r before the quote.
# Out:
# C:\some\name

# %% [markdown]
# String literals can span multiple lines and are delineated by triple-quotes: `"""..."""` or `'''...'''`. End of lines are automatically included in the string, but it's possible to prevent this by adding a `\` at the end of the line. For example, without a `\`, the following example includes an extra line at the beginning of the output:

# %%
print("""
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %% [markdown]
# Adding a `\` removes that extra line:

# %%
print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %% [markdown]
# Because Python doesn't provide a means for creating multi-line comments, developers often just use triple quotes for this purpose. In a Jupyter notebook, however, such quotes define a string literal which appears as the output of a code cell:

# %%
"""
Everything between the first three quotes, including new lines,
is part of the multi-line comment. Technically, the Python interpreter
simply sees the comment as a string, and because it's not otherwise
used in code, the string is ignored. Convenient, eh?
"""
# Out:
# "\nEverything between the first three quotes, including new lines,\nis part of the multi-line comment. Technically, the Python interpreter\nsimply sees the comment as a string, and because it's not otherwise\nused in code, the string is ignored. Convenient, eh?\n"

# %% [markdown]
# For this reason, it's best in notebooks to use the `#` comment character at the beginning of each line, or better still, just use a Markdown cell!

# %% [markdown]
# Strings can be *concatenated* (glued together) with the `+` operator, and repeated with `*`:

# %%
# 3 times 'un', followed by 'ium'
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %% [markdown]
# Two or more *string literals* (that is, the values enclosed in quotes) placed next to each other are automatically concatenated:

# %%
'Py' 'thon'
# Out:
# 'Python'

# %% [markdown]
# Encountering Errors:

# %% [markdown]
# Automatic concatenation works only with two literals; it does not work with variables or expressions, so the following cell produces an error:

# %%
prefix = 'Py'
prefix 'thon'  # Can't concatenate a variable and a string literal.
# Out:
#   File "<ipython-input-47-00ad70cd97bc>", line 2
#     prefix 'thon'  # Can't concatenate a variable and a string literal.
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# The following cell likewise produces an error:

# %%
('un' * 3) 'ium'
# Out:
#   File "<ipython-input-48-f4764cbe42a8>", line 1
#     ('un' * 3) 'ium'
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# To concatenate variables, or a variable and a literal, use `+`:

# %%
prefix = 'Py'
prefix + 'thon'
# Out:
# 'Python'

# %% [markdown]
# Automatic concatenation is particularly useful when you want to break up long strings:

# %%
text = ('Put several strings within parentheses '
        'to have them joined together.')
text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %% [markdown]
# Strings can be *indexed* (subscripted), with the first character having index 0. There is no separate character type; a character is simply a string of size one:

# %%
word = 'Python'
word[0]  # Character in position 0.
# Out:
# 'P'

# %%
word[5]  # Character in position 5.
# Out:
# 'n'

# %% [markdown]
# Indices may also be negative numbers, which means to start counting from the end of the string. Note that because -0 is the same as 0, negative indices start from -1:

# %%
word[-1]  # Last character.
# Out:
# 'n'

# %%
word[-2]  # Second-last character.
# Out:
# 'o'

# %%
word[-6]
# Out:
# 'P'

# %% [markdown]
# In addition to indexing, which extracts individual characters, Python also supports *slicing*, which extracts a substring. To slide, you indicate a *range* in the format `start:end`, where the start position is included but the end position is excluded:

# %%
word[0:2]  # Characters from position 0 (included) to 2 (excluded).
# Out:
# 'Py'

# %%
word[2:5]  # Characters from position 2 (included) to 5 (excluded).
# Out:
# 'tho'

# %% [markdown]
# If you omit either position, the default start position is 0 and the default end is the length of the string:

# %%
word[:2]   # Character from the beginning to position 2 (excluded).
# Out:
# 'Py'

# %%
word[4:]  # Characters from position 4 (included) to the end.
# Out:
# 'on'

# %%
word[-2:]  # Characters from the second-last (included) to the end.
# Out:
# 'on'

# %% [markdown]
# This characteristic means that `s[:i] + s[i:]` is always equal to `s`:

# %%
word[:2] + word[2:]
# Out:
# 'Python'

# %%
word[:4] + word[4:]
# Out:
# 'Python'

# %% [markdown]
# One way to remember how slices work is to think of the indices as pointing between characters, with the left edge of the first character numbered 0. Then the right edge of the last character of a string of *n* characters has index *n*. For example:

# %% [markdown]
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# -6  -5  -4  -3  -2  -1

# %% [markdown]
# The first row of numbers gives the position of the indices 0...6 in the string; the second row gives the corresponding negative indices. The slice from *i* to *j* consists of all characters between the edges labeled *i* and *j*, respectively.
#
# For non-negative indices, the length of a slice is the difference of the indices, if both are within bounds. For example, the length of `word[1:3]` is 2.
#
# Attempting to use an index that is too large results in an error:

# %%
word[42]  # The word only has 6 characters.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-e894f93573ea> in <module>()
# ----> 1 word[42]  # The word only has 6 characters.
#
# IndexError: string index out of range

# %% [markdown]
# However, when used in a range, an index that's too large defaults to the size of the string and does not give an error. This characteristic is useful when you always want to slice at a particular index regardless of the length of a string:

# %%
word[4:42]
# Out:
# 'on'

# %%
word[42:]
# Out:
# ''

# %% [markdown]
# Python strings are [immutable](https://docs.python.org/3.5/glossary.html#term-immutable), which means they cannot be changed. Therefore, assigning a value to an indexed position in a string results in an error:

# %%
word[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-91a956888ca7> in <module>()
# ----> 1 word[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# The following cell also produces an error:

# %%
word[2:] = 'py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-6488bbf78f5a> in <module>()
# ----> 1 word[2:] = 'py'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# A slice it itself a value that you can concatenate with other values using `+`:

# %%
'J' + word[1:]
# Out:
# 'Jython'

# %%
word[:2] + 'Py'
# Out:
# 'PyPy'

# %% [markdown]
# A slice, however, is not a string literal and cannot be used with automatic concatenation. The following code produces an error:

# %%
word[:2] 'Py'    # Slice is not a literal; produces an error
# Out:
#   File "<ipython-input-56-60be1c701626>", line 1
#     word[:2] 'Py'    # Slice is not a literal; produces an error
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# The built-in function [`len()`](https://docs.python.org/3.5/library/functions.html#len) returns the length of a string:

# %%
s = 'supercalifragilisticexpialidocious'
len(s)
# Out:
# 34

# %% [markdown]
# ### Lists

# %% [markdown]
# Python knows a number of _compound_ data types, which are used to group together other values. The most versatile is the [*list*](https://docs.python.org/3.5/library/stdtypes.html#typesseq-list), which can be written as a sequence of comma-separated values (items) between square brackets. Lists might contain items of different types, but usually the items all have the same type.

# %%
squares = [1, 4, 9, 16, 25]
squares
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Like strings (and all other built-in [sequence](https://docs.python.org/3.5/glossary.html#term-sequence) types), lists can be indexed and sliced:

# %%
squares[0]  # Indexing returns the item.
# Out:
# 1

# %%
squares[-1]
# Out:
# 25

# %%
squares[-3:]  # Slicing returns a new list.
# Out:
# [9, 16, 25]

# %% [markdown]
# All slice operations return a new list containing the requested elements. This means that the following slice returns a new (shallow) copy of the list:

# %%
squares[:]
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Lists also support concatenation with the `+` operator:

# %%
squares + [36, 49, 64, 81, 100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# Unlike strings, which are [immutable](https://docs.python.org/3.5/glossary.html#term-immutable), lists are a [mutable](https://docs.python.org/3.5/glossary.html#term-mutable) type, which means you can change any value in the list:

# %%
cubes = [1, 8, 27, 65, 125]  # Something's wrong here ...
4 ** 3  # the cube of 4 is 64, not 65!
# Out:
# 64

# %%
cubes[3] = 64  # Replace the wrong value.
cubes
# Out:
# [1, 8, 27, 64, 125]

# %% [markdown]
# Use the list's `append()` method to add new items to the end of the list:

# %%
# Append
cubes.append('append me!')
cubes.append(216)  # Add the cube of 6 ...
cubes.append(7 ** 3)  # and the cube of 7.
cubes
# Out:
# [1, 8, 27, 64, 125, 'append me!', 216, 343]

# %% [markdown]
# Use **pop** to "pop off" an item from the list. By default pop takes off the last index, but you can also specify which index to pop off. Let's see an example:

# %%
# Pop off the 0 indexed item
cubes.pop(0)
# Out:
# 1

# %%
# Assign the popped element, remember default popped index is -1
popped_item = cubes.pop()

# %%
cubes[100]  # This will throw an error because of list index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-6aa13b831e5c> in <module>()
# ----> 1 cubes[100] # This will throw an error because of list index out of range
#
# IndexError: list index out of range

# %% [markdown]
# You can even assign to slices, which can change the size of the list or clear it entirely:

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
# Replace some values.
letters[2:5] = ['C', 'D', 'E']
letters
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']

# %%
# Now remove them.
letters[2:5] = []
letters
# Out:
# ['a', 'b', 'f', 'g']

# %%
# Clear the list by replacing all the elements with an empty list.
letters[:] = []
letters
# Out:
# []

# %% [markdown]
# The built-in [`len()`](https://docs.python.org/3.5/library/functions.html#len) function also applies to lists:

# %%
letters = ['a', 'b', 'c', 'd']
len(letters)
# Out:
# 4

# %% [markdown]
# You can nest lists, which means to create lists that contain other lists. For example:

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[0][1]
# Out:
# 'b'

# %% [markdown]
# ### Basic List Methods
#
# If you are familiar with another programming language, you might start to draw parallels between arrays in another language and lists in Python. Lists in Python however, tend to be more flexible than arrays in other languages for a two good reasons: they have no fixed size (meaning we don't have to specify how big a list will be), and they have no fixed type constraint (like we've seen above).
#
# Let's go ahead and explore some more special methods for lists:

# %% [markdown]
# It should also be noted that lists indexing will return an error if there is no element at that index. For example:

# %% [markdown]
# We can use the **sort** method and the **reverse** methods to also effect your lists:

# %%
new_list = ['a', 'e', 'x', 'b', 'c']

# %%
# Show
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
# Use reverse to reverse order (this is permanent!)
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
# Use sort to sort the list (in this case alphabetical order, but for numbers it will go ascending)
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# ### Nesting Lists
# A great feature of of Python data structures is that they support *nesting*. This means we can have data structures within data structures. For example: A list inside a list.
#
# Let's see how this works!

# %%
# Let's make three lists
lst_1 = [1, 2, 3]
lst_2 = [4, 5, 6]
lst_3 = [7, 8, 9]

# Make a list of lists to form a matrix
matrix = [lst_1, lst_2, lst_3]

# %%
# Show
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# We can again use indexing to grab elements, but now there are two levels for the index. The items in the matrix object, and then the items inside that list!

# %%
# Grab first item in matrix object
matrix[0]
# Out:
# [1, 2, 3]

# %%
# Grab first item of the first item in the matrix object
matrix[0][0]
# Out:
# 1

# %% [markdown]
# ### Dictionaries
#
# We've been learning about *sequences* in Python but now we're going to switch gears and learn about *mappings* in Python. If you're familiar with other languages you can think of these Dictionaries as hash tables.
#
# This section will serve as a brief introduction to dictionaries and consist of:
#
#     1.) Constructing a Dictionary
#     2.) Accessing objects from a dictionary
#     3.) Nesting Dictionaries
#     4.) Basic Dictionary Methods
#
# So what are mappings? Mappings are a collection of objects that are stored by a *key*, unlike a sequence that stored objects by their relative position. This is an important distinction, since mappings won't retain order since they have objects defined by a key.
#
# A Python dictionary consists of a key and then an associated value. That value can be almost any Python object.
#
#
# ## Constructing a Dictionary
# Let's see how we can construct dictionaries to get a better understanding of how they work!

# %%
# Make a dictionary with {} and : to signify a key and a value
my_dict = {'key1': 'value1', 'key2': 'value2'}

# %%
# Call values by their key
my_dict['key2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 149' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000148?line=0'>1</a> # Call values by their key
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000148?line=1'>2</a> my_dict['key2']
#
# NameError: name 'my_dict' is not defined

# %% [markdown]
# Its important to note that dictionaries are very flexible in the data types they can hold. For example:

# %%
my_dict = {'key1': 123, 'key2': [12, 23, 33],
           'key3': ['item0', 'item1', 'item2']}

# %%
# Let's call items from the dictionary
my_dict['key3']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 152' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000151?line=0'>1</a> # Let's call items from the dictionary
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000151?line=1'>2</a> my_dict['key3']
#
# NameError: name 'my_dict' is not defined

# %%
# Can call an index on that value
my_dict['key3'][0]
# Out:
# 'item0'

# %%
# Can then even call methods on that value
my_dict['key3'][0].upper()
# Out:
# 'ITEM0'

# %% [markdown]
# We can affect the values of a key as well. For instance:

# %%
my_dict['key1']
# Out:
# 123

# %%
# Subtract 123 from the value
my_dict['key1'] = my_dict['key1'] - 123
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data science & ML\day_1 - demos_w10_asdex7qh\Day 1 - Demos\1752_day1_demo3 - Data Types in Python.ipynb Cell 157' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000156?line=0'>1</a> # Subtract 123 from the value
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20science%20%26%20ML/day_1%20-%20demos_w10_asdex7qh/Day%201%20-%20Demos/1752_day1_demo3%20-%20Data%20Types%20in%20Python.ipynb#ch0000156?line=1'>2</a> my_dict['key1'] = my_dict['key1'] - 123
#
# NameError: name 'my_dict' is not defined

# %%
# Check
my_dict['key1']
# Out:
# 0

# %% [markdown]
# A quick note, Python has a built-in method of doing a self subtraction or addition (or multiplication or division). We could have also used += or -= for the above statement. For example:

# %%
# Set the object equal to itself minus 123
my_dict['key1'] -= 123
my_dict['key1']
# Out:
# -123

# %% [markdown]
# We can also create keys by assignment. For instance if we started off with an empty dictionary, we could continually add to it:

# %%
# Create a new dictionary
d = {}

# %%
# Create a new key through assignment
d['animal'] = 'Dog'

# %%
# Can do this with any object
d['answer'] = 42

# %%
# Show
d
# Out:
# {'animal': 'Dog', 'answer': 42}

# %% [markdown]
# ### Nesting with Dictionaries
#
# Hopefully you're starting to see how powerful Python is with its flexibility of nesting objects and calling methods on them. Let's see a dictionary nested inside a dictionary:

# %%
# Dictionary nested inside a dictionary nested inside a dictionary
d = {'key1': {'nestkey': {'subnestkey': 'value'}}}

# %% [markdown]
# Wow! That's a quite the inception of dictionaries! Let's see how we can grab that value:

# %%
# Keep calling the keys
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %% [markdown]
# ### A few Dictionary Methods
#
# There are a few methods we can call on a dictionary. Let's get a quick introduction to a few of them:

# %%
# Create a typical dictionary
d = {'key1': 1, 'key2': 2, 'key3': 3}

# %%
# Method to return a list of all keys
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
# Method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
# Method to return tuples of all items  (we'll learn about tuples soon)
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])
